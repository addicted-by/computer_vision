# %%
import os
import cv2
import torch
import torchvision
from torchvision import transforms
from PIL import Image
import pickle

from catboost import CatBoostClassifier
import numpy as np
import pandas as pd
import time
import csv
from torch import nn

# %%
class ResNet101(nn.Module):
    def __init__(self, pretrained=False):
        super(ResNet101, self).__init__()
        self.model = torchvision.models.resnet101(pretrained=pretrained)
        
        self.model.fc = nn.Linear(2048, 10)
        self.linear = nn.Linear(10, 2)
        
        layers_count = len(list(self.model.parameters()))
        for i, parameter in enumerate(self.model.parameters()):
            if i < layers_count - 5:
                parameter.requires_grad = False
                
                
    def forward(self, X):
        logits = self.model(X)
        if self.training:
            logits = self.linear(logits)
        return logits

# %%
class ResNet152(nn.Module):
    def __init__(self, pretrained=False):
        super(ResNet152, self).__init__()
        self.model = torchvision.models.resnet152(pretrained=pretrained)
        
        self.model.fc = nn.Linear(2048, 10)
        self.linear = nn.Linear(10, 2)
        
        layers_count = len(list(self.model.parameters()))
        for i, parameter in enumerate(self.model.parameters()):
            if i < layers_count - 10:
                parameter.requires_grad = False
                
                
    def forward(self, X):
        logits = self.model(X)
        if self.training:
            logits = self.linear(logits)
        return logits

# %%
class DenseNet(nn.Module):
    def __init__(self, pretrained=False):
        super(DenseNet, self).__init__()
        self.model = torchvision.models.densenet201(pretrained=pretrained)
        
        self.model.classifier = nn.Linear(1920, 10)
        self.linear = nn.Linear(10, 2)
        
        layers_count = len(list(self.model.parameters()))
        for i, parameter in enumerate(self.model.parameters()):
            if i < layers_count - 5:
                parameter.requires_grad = False
                
                
    def forward(self, X):
        logits = self.model(X)
        if self.training:
            logits = self.linear(logits)
        return logits

# %%
transform = torchvision.transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize(350),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
DATA_FOLDER = './data/6/'
MODEL_FOLDER = './models/stacking/'
VIDEO_PATH = os.path.join(DATA_FOLDER, 'video.mp4')
OUTPUT_PATH = os.path.join(DATA_FOLDER, 'predictions.txt')

# %%
resnet152 = ResNet152()
resnet152.load_state_dict(torch.load(os.path.join(MODEL_FOLDER, 'ResNet152.pt')))
resnet152.eval();

resnet101 = ResNet101()
resnet101.load_state_dict(torch.load(os.path.join(MODEL_FOLDER, 'ResNet101.pt')))
resnet101.eval();

densenet = DenseNet()
densenet.load_state_dict(torch.load(os.path.join(MODEL_FOLDER, 'DenseNet.pt')))
densenet.eval();

boosting = CatBoostClassifier().load_model(os.path.join(MODEL_FOLDER, 'boosting.model'))
random_forest = pickle.load(open(os.path.join(MODEL_FOLDER, 'random_forest.pkl'), 'rb'))
svm = pickle.load(open(os.path.join(MODEL_FOLDER, 'svm.pkl'), 'rb'))
scaler = pickle.load(open(os.path.join(MODEL_FOLDER, 'scaler.pkl'), 'rb'))
# extra_tree = pickle.load(open(os.path.join(MODEL_FOLDER, 'extra_tree.pkl'), 'rb'))
# Out:
# c:\Users\User\Documents\Hackaton 2022\Attempts\venv\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\User\Documents\Hackaton 2022\Attempts\venv\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\User\Documents\Hackaton 2022\Attempts\venv\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator SVC from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\User\Documents\Hackaton 2022\Attempts\venv\lib\site-packages\sklearn\base.py:329: UserWarning: Trying to unpickle estimator StandardScaler from version 0.24.2 when using version 1.0.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/modules/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
def get_prediction(frame):
    WEIGHTS = np.array([1, 1.2])
    transformed_image = transform(frame)
    
    resnet101_logits = scaler.transform(resnet101(transformed_image[None,]).detach().numpy())
#     resnet152_logits = resnet152(transformed_image[None,]).detach().numpy()
    densenet_logits = scaler.transform(densenet(transformed_image[None,]).detach().numpy())
    
    predictions = np.array([0, 0])
    
    boosting_resnet101_probas = boosting.predict_proba(resnet101_logits)
#     boosting_resnet152_probas = boosting.predict_proba(resnet152_logits)
    boosting_densenet_probas = boosting.predict_proba(densenet_logits)
    
    forest_resnet101_probas = random_forest.predict_proba(resnet101_logits)
#     forest_resnet152_probas = random_forest.predict_proba(resnet152_logits)
    forest_densenet_probas = random_forest.predict_proba(densenet_logits)
    
    svm_resnet101_probas = svm.predict_proba(resnet101_logits)
#     svm_resnet152_probas = svm.predict_proba(resnet152_logits)
    svm_densenet_probas = svm.predict_proba(densenet_logits)
    
    predictions = (boosting_resnet101_probas + boosting_densenet_probas + 
                forest_resnet101_probas + forest_densenet_probas + 
                svm_resnet101_probas + svm_densenet_probas) / 4
    predictions = predictions * WEIGHTS
    predictions /= predictions.sum()
    return predictions

# %%
video_capture = cv2.VideoCapture(VIDEO_PATH)
assert video_capture.isOpened()

FPS = int(video_capture.get(cv2.CAP_PROP_FPS))
DURATION = int(video_capture.get(cv2.CAP_PROP_FRAME_COUNT) / FPS)
SECONDS_PER_FRAME = 1

print("FPS: ", FPS)
print("Duration: ", DURATION)

previous_class = None
current_start = None

segments = []
for current_video_position in range(0, DURATION + SECONDS_PER_FRAME, SECONDS_PER_FRAME):
    video_capture.set(cv2.CAP_PROP_POS_MSEC, current_video_position * 1000)
    ret, frame = video_capture.read()
    if ret == False:
        break
    
    probas = get_prediction(frame)
    predicted_class = np.argmax(probas)
    
    if previous_class is None:
        current_start = current_video_position
        previous_class = predicted_class
    if predicted_class != previous_class:
        segments.append([current_start, current_video_position - 1, previous_class])
        current_start = current_video_position - 1
        previous_class = predicted_class
    
    print('Predicted class at second', current_video_position, 'is', predicted_class, 'with probas', probas)

segments.append([current_start, current_video_position, previous_class])
video_capture.release()
cv2.destroyAllWindows()
# Out:
# FPS:  30
# Duration:  120
# Predicted class at second 0 is 0 with probas [[0.70781026 0.29218974]]
# Predicted class at second 1 is 0 with probas [[0.699358 0.300642]]
# Predicted class at second 2 is 0 with probas [[0.71843811 0.28156189]]
# Predicted class at second 3 is 0 with probas [[0.73157397 0.26842603]]
# Predicted class at second 4 is 0 with probas [[0.68514336 0.31485664]]
# Predicted class at second 5 is 0 with probas [[0.71148229 0.28851771]]
# Predicted class at second 6 is 0 with probas [[0.72873458 0.27126542]]
# Predicted class at second 7 is 0 with probas [[0.72266496 0.27733504]]
# Predicted class at second 8 is 0 with probas [[0.74454016 0.25545984]]
# Predicted class at second 9 is 0 with probas [[0.71847136 0.28152864]]
# Predicted class at second 10 is 1 with probas [[0.19587264 0.80412736]]
# Predicted class at second 11 is 1 with probas [[0.1872219 0.8127781]]
# Predicted class at second 12 is 1 with probas [[0.1785638 0.8214362]]
# Predicted class at second 13 is 1 with probas [[0.19101834 0.80898166]]
# Predicted class at second 14 is 1 with probas [[0.19545604 0.80454396]]
# Predicted class at second 15 is 1 with probas [[0.10833751 0.89166249]]
# Predicted class at second 16 is 1 with probas [[0.17222846 0.82777154]]
# Predicted class at second 17 is 1 with probas [[0.18635293 0.81364707]]
# Predicted class at second 18 is 1 with probas [[0.40354929 0.59645071]]
# Predicted class at second 19 is 1 with probas [[0.24747784 0.75252216]]
# Predicted class at second 20 is 1 with probas [[0.2994923 0.7005077]]
# Predicted class at second 21 is 1 with probas [[0.2973483 0.7026517]]
# Predicted class at second 22 is 1 with probas [[0.21899733 0.78100267]]
# Predicted class at second 23 is 1 with probas [[0.11939011 0.88060989]]
# Predicted class at second 24 is 1 with probas [[0.09363854 0.90636146]]
# Predicted class at second 25 is 1 with probas [[0.22711984 0.77288016]]
# Predicted class at second 26 is 1 with probas [[0.19143435 0.80856565]]
# Predicted class at second 27 is 1 with probas [[0.17129596 0.82870404]]
# Predicted class at second 28 is 1 with probas [[0.09567138 0.90432862]]
# Predicted class at second 29 is 1 with probas [[0.14433551 0.85566449]]
# Predicted class at second 30 is 0 with probas [[0.77149747 0.22850253]]
# Predicted class at second 31 is 0 with probas [[0.78238248 0.21761752]]
# Predicted class at second 32 is 0 with probas [[0.76103769 0.23896231]]
# Predicted class at second 33 is 0 with probas [[0.77981715 0.22018285]]
# Predicted class at second 34 is 0 with probas [[0.76800723 0.23199277]]
# Predicted class at second 35 is 0 with probas [[0.74736991 0.25263009]]
# Predicted class at second 36 is 0 with probas [[0.77806468 0.22193532]]
# Predicted class at second 37 is 0 with probas [[0.78041644 0.21958356]]
# Predicted class at second 38 is 0 with probas [[0.85857736 0.14142264]]
# Predicted class at second 39 is 0 with probas [[0.70381229 0.29618771]]
# Predicted class at second 40 is 0 with probas [[0.79038455 0.20961545]]
# Predicted class at second 41 is 0 with probas [[0.7431788 0.2568212]]
# Predicted class at second 42 is 0 with probas [[0.78878857 0.21121143]]
# Predicted class at second 43 is 0 with probas [[0.73306335 0.26693665]]
# Predicted class at second 44 is 0 with probas [[0.72952717 0.27047283]]
# Predicted class at second 45 is 0 with probas [[0.68889301 0.31110699]]
# Predicted class at second 46 is 0 with probas [[0.77246381 0.22753619]]
# Predicted class at second 47 is 0 with probas [[0.74527123 0.25472877]]
# Predicted class at second 48 is 0 with probas [[0.73626968 0.26373032]]
# Predicted class at second 49 is 1 with probas [[0.41263676 0.58736324]]
# Predicted class at second 50 is 1 with probas [[0.45752514 0.54247486]]
# Predicted class at second 51 is 1 with probas [[0.47758607 0.52241393]]
# Predicted class at second 52 is 1 with probas [[0.46815817 0.53184183]]
# Predicted class at second 53 is 0 with probas [[0.50710302 0.49289698]]
# Predicted class at second 54 is 0 with probas [[0.64600687 0.35399313]]
# Predicted class at second 55 is 1 with probas [[0.49955908 0.50044092]]
# Predicted class at second 56 is 1 with probas [[0.42867519 0.57132481]]
# Predicted class at second 57 is 1 with probas [[0.40117662 0.59882338]]
# Predicted class at second 58 is 0 with probas [[0.5680405 0.4319595]]
# Predicted class at second 59 is 1 with probas [[0.29402058 0.70597942]]
# Predicted class at second 60 is 1 with probas [[0.17268235 0.82731765]]
# Predicted class at second 61 is 1 with probas [[0.15973488 0.84026512]]
# Predicted class at second 62 is 1 with probas [[0.18035154 0.81964846]]
# Predicted class at second 63 is 1 with probas [[0.17501308 0.82498692]]
# Predicted class at second 64 is 1 with probas [[0.2167978 0.7832022]]
# Predicted class at second 65 is 1 with probas [[0.23258313 0.76741687]]
# Predicted class at second 66 is 1 with probas [[0.18542024 0.81457976]]
# Predicted class at second 67 is 1 with probas [[0.13115099 0.86884901]]
# Predicted class at second 68 is 1 with probas [[0.21487896 0.78512104]]
# Predicted class at second 69 is 1 with probas [[0.22062018 0.77937982]]
# Predicted class at second 70 is 1 with probas [[0.16713494 0.83286506]]
# Predicted class at second 71 is 1 with probas [[0.16595976 0.83404024]]
# Predicted class at second 72 is 1 with probas [[0.32335503 0.67664497]]
# Predicted class at second 73 is 1 with probas [[0.10637549 0.89362451]]
# Predicted class at second 74 is 1 with probas [[0.16863986 0.83136014]]
# Predicted class at second 75 is 1 with probas [[0.10285605 0.89714395]]
# Predicted class at second 76 is 1 with probas [[0.0877657 0.9122343]]
# Predicted class at second 77 is 1 with probas [[0.07609369 0.92390631]]
# Predicted class at second 78 is 1 with probas [[0.14957861 0.85042139]]
# Predicted class at second 79 is 1 with probas [[0.2683821 0.7316179]]
# Predicted class at second 80 is 1 with probas [[0.40912183 0.59087817]]
# Predicted class at second 81 is 1 with probas [[0.48365731 0.51634269]]
# Predicted class at second 82 is 1 with probas [[0.36107331 0.63892669]]
# Predicted class at second 83 is 1 with probas [[0.31506399 0.68493601]]
# Predicted class at second 84 is 1 with probas [[0.41341747 0.58658253]]
# Predicted class at second 85 is 1 with probas [[0.25114952 0.74885048]]
# Predicted class at second 86 is 1 with probas [[0.455235 0.544765]]
# Predicted class at second 87 is 1 with probas [[0.30571029 0.69428971]]
# Predicted class at second 88 is 1 with probas [[0.33262772 0.66737228]]
# Predicted class at second 89 is 1 with probas [[0.21050404 0.78949596]]
# Predicted class at second 90 is 1 with probas [[0.3090206 0.6909794]]
# Predicted class at second 91 is 1 with probas [[0.27449808 0.72550192]]
# Predicted class at second 92 is 1 with probas [[0.25172903 0.74827097]]
# Predicted class at second 93 is 1 with probas [[0.24994564 0.75005436]]
# Predicted class at second 94 is 1 with probas [[0.34423279 0.65576721]]
# Predicted class at second 95 is 1 with probas [[0.27010941 0.72989059]]
# Predicted class at second 96 is 1 with probas [[0.19210793 0.80789207]]
# Predicted class at second 97 is 1 with probas [[0.4367263 0.5632737]]
# Predicted class at second 98 is 0 with probas [[0.72450765 0.27549235]]
# Predicted class at second 99 is 0 with probas [[0.72885881 0.27114119]]
# Predicted class at second 100 is 0 with probas [[0.69383533 0.30616467]]
# Predicted class at second 101 is 0 with probas [[0.70578563 0.29421437]]
# Predicted class at second 102 is 0 with probas [[0.73732957 0.26267043]]
# Predicted class at second 103 is 0 with probas [[0.74151249 0.25848751]]
# Predicted class at second 104 is 0 with probas [[0.73836818 0.26163182]]
# Predicted class at second 105 is 0 with probas [[0.73269048 0.26730952]]
# Predicted class at second 106 is 0 with probas [[0.70163804 0.29836196]]
# Predicted class at second 107 is 0 with probas [[0.76768325 0.23231675]]
# Predicted class at second 108 is 0 with probas [[0.58102192 0.41897808]]
# Predicted class at second 109 is 0 with probas [[0.58189676 0.41810324]]
# Predicted class at second 110 is 0 with probas [[0.5522118 0.4477882]]
# Predicted class at second 111 is 1 with probas [[0.28922909 0.71077091]]
# Predicted class at second 112 is 0 with probas [[0.55720821 0.44279179]]
# Predicted class at second 113 is 0 with probas [[0.52663678 0.47336322]]
# Predicted class at second 114 is 1 with probas [[0.44877378 0.55122622]]
# Predicted class at second 115 is 1 with probas [[0.40140904 0.59859096]]
# Predicted class at second 116 is 0 with probas [[0.50389451 0.49610549]]
# Predicted class at second 117 is 1 with probas [[0.46904521 0.53095479]]
# Predicted class at second 118 is 1 with probas [[0.46964645 0.53035355]]
# Predicted class at second 119 is 1 with probas [[0.40778191 0.59221809]]
# Predicted class at second 120 is 1 with probas [[0.39430329 0.60569671]]

# %%
pd.DataFrame(segments).set_index(0).to_csv(OUTPUT_PATH, sep=' ', header=False)

# %%
OUTPUT_PATH
# Out:
# './data/6/predictions.txt'
